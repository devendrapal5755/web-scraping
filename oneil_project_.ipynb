# %% [markdown]
# Save API as api_key

# %%
api_key="AIzaSyBlXGpRre8K3J7dpSyuyz5LA8_1ZoqnZeM"

# %% [markdown]
# install google-api-python-client

# %%
pip install google-api-python-client

# %% [markdown]
# Build import

# %%
from apiclient.discovery import build

# %% [markdown]
# by using build use customesearch engine

# %%
resource = build("customsearch","v1", developerKey=api_key).cse()

# %% [markdown]
# import pandas for read csv file

# %%
import pandas as pd

# %% [markdown]
# read the csv file

# %%
data=pd.read_csv("/content/drive/My Drive/GBAS.csv")

# %%
data.head()
# Out:
#      Brand               Reference  ... Product Page URL Price(Euros)
# 0  O'NEILL   0A4972-9950 BLACK AOP  ...              NaN          NaN
# 1  O'NEILL    9P1070-5056 Ink Blue  ...              NaN          NaN
# 2  O'NEILL  9P1070-6077 Winter Mos  ...              NaN          NaN
# 3  O'NEILL    8P1072-5056 Ink Blue  ...              NaN          NaN
# 4  O'NEILL   8P1072-5112 Surf Blue  ...              NaN          NaN
#
# [5 rows x 7 columns]

# %%
code=data['Google Search Code']

# %% [markdown]
# save google search code in code

# %%
result=resource.list(q='code', cx='1a286726259098a57').execute()

# %%
result['items']
# Out:
# [{'cacheId': 'ClWJ1vW1ZP4J',
#   'displayLink': 'www.oneill.com',
#   'formattedUrl': 'https://www.oneill.com/eu/en/shop/wetsuits/series',
#   'htmlFormattedUrl': 'https://www.oneill.com/eu/en/shop/wetsuits/series',
#   'htmlSnippet': '<b>Code</b> Red Urethane Coated Zipper • Anti-Flush Barrier (Z.E.N Zip) Construction: • <br>\nUltraFlex: Fully taped Seams • Chest/Back: Smoothskin Carbon-Firewall',
#   'htmlTitle': 'Wetsuit Series | O&#39;Neill',
#   'kind': 'customsearch#result',
#   'link': 'https://www.oneill.com/eu/en/shop/wetsuits/series',
#   'pagemap': {'cse_image': [{'src': 'https://www.oneill.com/on/demandware.static/Sites-ONG-Site/-/default/dw1f585334/images/logo.svg'}],
#    'cse_thumbnail': [{'height': '25',
#      'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcT6F_2Ldp3IRs874KywP1KwhZqKsCmNWXHw1BAtE8UAna7vatjeMy6xVA',
#      'width': '77'}],
#    'metatags': [{'fb:app_id': '219013978286041',
#      'google': 'notranslate',
# ...

# %%
result['items']
# Out:
# [{'cacheId': 'ClWJ1vW1ZP4J',
#   'displayLink': 'www.oneill.com',
#   'formattedUrl': 'https://www.oneill.com/eu/en/shop/wetsuits/series',
#   'htmlFormattedUrl': 'https://www.oneill.com/eu/en/shop/wetsuits/series',
#   'htmlSnippet': '<b>Code</b> Red Urethane Coated Zipper • Anti-Flush Barrier (Z.E.N Zip) Construction: • <br>\nUltraFlex: Fully taped Seams • Chest/Back: Smoothskin Carbon-Firewall',
#   'htmlTitle': 'Wetsuit Series | O&#39;Neill',
#   'kind': 'customsearch#result',
#   'link': 'https://www.oneill.com/eu/en/shop/wetsuits/series',
#   'pagemap': {'cse_image': [{'src': 'https://www.oneill.com/on/demandware.static/Sites-ONG-Site/-/default/dw1f585334/images/logo.svg'}],
#    'cse_thumbnail': [{'height': '25',
#      'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcT6F_2Ldp3IRs874KywP1KwhZqKsCmNWXHw1BAtE8UAna7vatjeMy6xVA',
#      'width': '77'}],
#    'metatags': [{'fb:app_id': '219013978286041',
#      'google': 'notranslate',
# ...

# %% [markdown]
# check product details with give code

# %%
result=resource.list(q='9P1070-6077	', cx='1a286726259098a57').execute()

# %%
result
# Out:
# {'context': {'title': 'Oneill'},
#  'items': [{'cacheId': '-i1p8M5BU_IJ',
#    'displayLink': 'www.oneill.com',
#    'formattedUrl': 'https://www.oneill.com/de/en/charger-parka.../9P1070-6077-164.html',
#    'htmlFormattedUrl': 'https://www.oneill.com/de/en/charger-parka.../<b>9P1070</b>-<b>6077</b>-164.html',
#    'htmlSnippet': '<b>9P1070</b>-<b>6077</b>-164; Wash Instructions: Free Delivery over €75. 60 day free return <br>\npolicy. Sign up for our newsletter. Find a store &middot; Facebook Instagram Youtube&nbsp;...',
#    'htmlTitle': 'Charger Parka Jacket O&#39;Neill',
#    'kind': 'customsearch#result',
#    'link': 'https://www.oneill.com/de/en/charger-parka-jacket/9P1070-6077-164.html',
#    'pagemap': {'cse_image': [{'src': 'https://www.oneill.com/on/demandware.static/-/Sites-master-catalog/default/dw36d6fed6/images_19/9P1/9P1070_6077_MODEL_1.JPG'}],
#     'cse_thumbnail': [{'height': '278',
# ...

# %% [markdown]
# Extract link

# %%
for ite in result['items']:
      print(ite['link'],ite['snippet'])
# Out:
# https://www.oneill.com/eu/en/shop/wetsuits/series Code Red Urethane Coated Zipper • Anti-Flush Barrier (Z.E.N Zip) Construction: •
# UltraFlex: Fully taped Seams • Chest/Back: Smoothskin Carbon-Firewall
# https://www.oneill.com/de/en/shop/inspiration/about-oneill/social-responsibility Click here to download our code of conduct. Click here to download our 2018
# sustainability report. Click here to download our 2019 sustainability report. O'Neill
#  ...
# https://www.oneill.com/fr/en/montara-wallet/8A4200-9010-0.html Details. Article nr.: 8A4200-9010-0; Wash Instructions: Use promo code
# SUMMERINSIDE. 60 day free return policy. Sign up for our newsletter. Find a
# store.
# https://www.oneill.com/de/en/flexifit-corp-cap/8A4112-5056-SM.html Select Accessories Size. Add to Cart. Use promo code SUMMERINSIDE. 60 day
# free return policy. 60 day free return policy. Use promo code SUMMERINSIDE.
# ...
